# %% [markdown]
# <a href="https://colab.research.google.com/github/millerpro/fighters/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from fastai.vision import *

# %%
folder = 'a320'
file = 'a320.txt'

# %%
folder = 'b737'
file = 'b737.txt'

# %%
path = Path('fighters')
dest = path/folder
dest.mkdir(parents=True, exist_ok=True)

# %%
path.ls()
# Out:
# [PosixPath('fighters/.ipynb_checkpoints'),
#  PosixPath('fighters/a320.txt'),
#  PosixPath('fighters/b737'),
#  PosixPath('fighters/a320'),
#  PosixPath('fighters/b737.txt')]

# %%
classes = ['a320', 'b737']

# %%
#download_images(path/file, dest, max_pics=200)

# %%
for c in classes:
  print(c)
  verify_images(path/c, delete=True, max_size=500)
# Out:
# a320
# b737

# %%
np.random.seed(42)
data = ImageDataBunch.from_folder(path, train=".", valid_pct=0.2,
        ds_tfms=get_transforms(), size=224, num_workers=2).normalize(imagenet_stats)

# %%
data.classes
# Out:
# ['a320', 'b737']

# %%
data.show_batch(rows=3, figsize=(7,8))

# %%
data.classes, data.c, len(data.train_ds), len(data.valid_ds)
# Out:
# (['a320', 'b737'], 2, 72, 18)

# %%
learn = cnn_learner(data, models.resnet101, metrics=error_rate)
# Out:
# Downloading: "https://download.pytorch.org/models/resnet101-63fe2227.pth" to /root/.cache/torch/hub/checkpoints/resnet101-63fe2227.pth
# ...
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-25-56c42ce76ed6> in <module>()
# ----> 1 learn = cnn_learner(data, models.resnet101, metrics=error_rate)
#
# /usr/local/lib/python3.7/dist-packages/fastai/vision/learner.py in cnn_learner(data, base_arch, cut, pretrained, lin_ftrs, ps, custom_head, split_on, bn_final, init, concat_pool, **kwargs)
#     100     model = create_cnn_model(base_arch, data.c, cut, pretrained, lin_ftrs, ps=ps, custom_head=custom_head,
#     101         bn_final=bn_final, concat_pool=concat_pool)
# --> 102     learn = Learner(data, model, **kwargs)
#     103     learn.split(split_on or meta['split'])
#     104     if pretrained: learn.freeze()
#
# ...

# %%
learn.fit_one_cycle(50)
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='50' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/50 00:00<00:00]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#
#     <div>
# ...

# %%
learn.save('stage-1')

# %%
learn.unfreeze()

# %%
learn.lr_find()

# %%
learn.recorder.plot()

# %%
learn.fit_one_cycle(10, max_lr=slice(1e-05,1e-04))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.007074</td>
#       <td>1.560604</td>
#       <td>0.416667</td>
#       <td>00:02</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.004240</td>
#       <td>1.597291</td>
#       <td>0.416667</td>
#       <td>00:02</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.005955</td>
#       <td>1.529264</td>
#       <td>0.416667</td>
#       <td>00:02</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.004587</td>
#       <td>1.480921</td>
#       <td>0.375000</td>
#       <td>00:02</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.004689</td>
#       <td>1.378586</td>
#       <td>0.333333</td>
#       <td>00:02</td>
#     </tr>
#     <tr>
#       <td>5</td>
# ...

# %%
learn.save('stage-2')

# %%
learn.load('stage-2')

# %%
interp = ClassificationInterpretation.from_learner(learn)

# %%
interp.plot_confusion_matrix()

# %%
interp.plot_top_losses(9, figsize=(30,22))
